# %%
log = """
Train Set Size: 975896
Valid Set Size: 209119
Test Set Size: 209123
logits mean/std: -0.057354919612407684 0.0915069654583931
probs min/max/mean: 0.42440685629844666 0.5356348156929016 0.4856959581375122
y label mean: 0.3125
pos logits mean: -0.06725534051656723
neg logits mean: -0.05285472050309181
Valid preds label counts: tensor([15, 17])
Valid true label counts: tensor([19, 13])
🎉 New best validation loss: 0.3912. Saving model...

[Epoch 1/100]
  [Train] LR: 0.001000 | Loss: 0.4119
  [Valid] Loss: 0.3912 | Acc: 0.8169, Prec: 0.8145, Rec: 0.8148, F1: 0.8147, AUC: 0.9014
Valid preds label counts: tensor([15, 17])
Valid true label counts: tensor([19, 13])
🎉 New best validation loss: 0.3861. Saving model...

[Epoch 2/100]
  [Train] LR: 0.001000 | Loss: 0.3917
  [Valid] Loss: 0.3861 | Acc: 0.8187, Prec: 0.8167, Rec: 0.8198, F1: 0.8175, AUC: 0.9056
Valid preds label counts: tensor([17, 15])
Valid true label counts: tensor([19, 13])
🎉 New best validation loss: 0.3789. Saving model...

[Epoch 3/100]
  [Train] LR: 0.001000 | Loss: 0.3839
  [Valid] Loss: 0.3789 | Acc: 0.8244, Prec: 0.8245, Rec: 0.8187, F1: 0.8208, AUC: 0.9075
Valid preds label counts: tensor([17, 15])
Valid true label counts: tensor([19, 13])

[Epoch 4/100]
  [Train] LR: 0.001000 | Loss: 0.3826
  [Valid] Loss: 0.3901 | Acc: 0.8214, Prec: 0.8211, Rec: 0.8160, F1: 0.8179, AUC: 0.9042
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 5/100]
  [Train] LR: 0.001000 | Loss: 0.3865
  [Valid] Loss: 0.3815 | Acc: 0.8214, Prec: 0.8193, Rec: 0.8185, F1: 0.8189, AUC: 0.9079
Valid preds label counts: tensor([17, 15])
Valid true label counts: tensor([19, 13])
🎉 New best validation loss: 0.3761. Saving model...

[Epoch 6/100]
  [Train] LR: 0.001000 | Loss: 0.3812
  [Valid] Loss: 0.3761 | Acc: 0.8257, Prec: 0.8252, Rec: 0.8206, F1: 0.8223, AUC: 0.9098
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 7/100]
  [Train] LR: 0.001000 | Loss: 0.3811
  [Valid] Loss: 0.3812 | Acc: 0.8226, Prec: 0.8207, Rec: 0.8195, F1: 0.8200, AUC: 0.9069
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 8/100]
  [Train] LR: 0.001000 | Loss: 0.3823
  [Valid] Loss: 0.3785 | Acc: 0.8263, Prec: 0.8253, Rec: 0.8219, F1: 0.8233, AUC: 0.9084
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 9/100]
  [Train] LR: 0.001000 | Loss: 0.3827
  [Valid] Loss: 0.3909 | Acc: 0.8224, Prec: 0.8244, Rec: 0.8151, F1: 0.8180, AUC: 0.9003
Valid preds label counts: tensor([17, 15])
Valid true label counts: tensor([19, 13])

[Epoch 10/100]
  [Train] LR: 0.001000 | Loss: 0.3836
  [Valid] Loss: 0.3952 | Acc: 0.8167, Prec: 0.8169, Rec: 0.8105, F1: 0.8127, AUC: 0.8997
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 11/100]
  [Train] LR: 0.001000 | Loss: 0.3922
  [Valid] Loss: 0.4511 | Acc: 0.8066, Prec: 0.8071, Rec: 0.8110, F1: 0.8061, AUC: 0.8435
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 12/100]
  [Train] LR: 0.001000 | Loss: 0.3983
  [Valid] Loss: 0.3956 | Acc: 0.8202, Prec: 0.8178, Rec: 0.8191, F1: 0.8183, AUC: 0.8998
Valid preds label counts: tensor([17, 15])
Valid true label counts: tensor([19, 13])

[Epoch 13/100]
  [Train] LR: 0.001000 | Loss: 0.4097
  [Valid] Loss: 0.4060 | Acc: 0.8132, Prec: 0.8120, Rec: 0.8085, F1: 0.8099, AUC: 0.8942
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 14/100]
  [Train] LR: 0.001000 | Loss: 0.3894
  [Valid] Loss: 0.3826 | Acc: 0.8240, Prec: 0.8238, Rec: 0.8185, F1: 0.8204, AUC: 0.9068
Valid preds label counts: tensor([17, 15])
Valid true label counts: tensor([19, 13])

[Epoch 15/100]
  [Train] LR: 0.001000 | Loss: 0.3925
  [Valid] Loss: 0.4296 | Acc: 0.8169, Prec: 0.8172, Rec: 0.8107, F1: 0.8129, AUC: 0.8669
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 16/100]
  [Train] LR: 0.001000 | Loss: 0.4140
  [Valid] Loss: 0.4033 | Acc: 0.8188, Prec: 0.8164, Rec: 0.8169, F1: 0.8166, AUC: 0.8954
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 17/100]
  [Train] LR: 0.000100 | Loss: 0.3953
  [Valid] Loss: 0.3861 | Acc: 0.8232, Prec: 0.8214, Rec: 0.8200, F1: 0.8206, AUC: 0.9044
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 18/100]
  [Train] LR: 0.000100 | Loss: 0.3767
  [Valid] Loss: 0.3764 | Acc: 0.8265, Prec: 0.8255, Rec: 0.8221, F1: 0.8235, AUC: 0.9091
Valid preds label counts: tensor([15, 17])
Valid true label counts: tensor([19, 13])

[Epoch 19/100]
  [Train] LR: 0.000100 | Loss: 0.3754
  [Valid] Loss: 0.3781 | Acc: 0.8272, Prec: 0.8262, Rec: 0.8229, F1: 0.8242, AUC: 0.9085
Valid preds label counts: tensor([16, 16])
Valid true label counts: tensor([19, 13])

[Epoch 20/100]
  [Train] LR: 0.000100 | Loss: 0.3751
  [Valid] Loss: 0.3772 | Acc: 0.8281, Prec: 0.8268, Rec: 0.8242, F1: 0.8253, AUC: 0.9088
Valid preds label counts: tensor([14, 18])
Valid true label counts: tensor([19, 13])
🛑 Early stopping triggered after 15 epochs without improvement.

[Epoch 21/100]
  [Train] LR: 0.000100 | Loss: 0.3756
  [Valid] Loss: 0.3783 | Acc: 0.8287, Prec: 0.8274, Rec: 0.8248, F1: 0.8259, AUC: 0.9083

--- Early Stopping activated. Learning terminated. ---

--- 학습 완료 ---

저장되어 있는 전처리된 데이터가 있습니다. 해당 데이터를 불러오는 중..
불러오기 완료
Train Set Size: 975896
Valid Set Size: 209119
Test Set Size: 209123
Valid preds label counts: tensor([21, 11])
Valid true label counts: tensor([21, 11])

[Test] Loss: 0.3763 | Acc: 0.8254, Prec: 0.8248, Rec: 0.8205, F1: 0.8221, AUC: 0.9094
"""

# %%
import re
import matplotlib.pyplot as plt

# 정규식으로 Epoch와 Validation Acc 추출
epochs = []
val_accs = []

current_epoch = None

for line in log.strip().split("\n"):
    # 1) Epoch 줄 찾기: 예) [Epoch 3/100]
    epoch_match = re.search(r"\[Epoch\s+(\d+)/\d+\]", line)
    if epoch_match:
        current_epoch = int(epoch_match.group(1))
        continue

    # 2) Valid 줄에서 Acc 찾기: 예) [Valid] Loss: ... | Acc: 0.8244, ...
    acc_match = re.search(r"\[Valid\].*Acc:\s*([0-9.]+)", line)
    if acc_match and current_epoch is not None:
        acc = float(acc_match.group(1))

        epochs.append(current_epoch)
        val_accs.append(acc)

# 그래프 그리기
plt.plot(epochs, val_accs, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy over Epochs")
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
import re
import matplotlib.pyplot as plt

epochs = []
val_accs = []
val_losses = []

current_epoch = None

for line in log.strip().split("\n"):
    # 1) Epoch 줄: [Epoch 3/100]
    epoch_match = re.search(r"\[Epoch\s+(\d+)/\d+\]", line)
    if epoch_match:
        current_epoch = int(epoch_match.group(1))
        continue

    # 2) Valid 줄에서 Loss와 Acc 추출
    valid_match = re.search(
        r"\[Valid\]\s*Loss:\s*([0-9.]+).*Acc:\s*([0-9.]+)", line
    )

    if valid_match and current_epoch is not None:
        loss = float(valid_match.group(1))
        acc = float(valid_match.group(2))

        epochs.append(current_epoch)
        val_losses.append(loss)
        val_accs.append(acc)

# ---- 그래프 1: Validation Loss ----
plt.figure(figsize=(8, 4))
plt.plot(epochs, val_losses, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Validation Loss over Epochs")
plt.grid(True)
plt.xticks(epochs)
plt.show()

# ---- 그래프 2: Validation Accuracy ----
plt.figure(figsize=(8, 4))
plt.plot(epochs, val_accs, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy over Epochs")
plt.grid(True)
plt.xticks(epochs)
plt.show()

# %%
log = '''
  Best loss updated to 17.4351. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.12it/s]
Epoch: 2 - loss:  0.7684
  Best loss updated to 0.7684. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:15<00:00, 13.03it/s]
Epoch: 3 - loss:  0.7403
  Best loss updated to 0.7403. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:15<00:00, 12.90it/s]
Epoch: 4 - loss:  0.7330
  Best loss updated to 0.7330. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:15<00:00, 13.02it/s]
Epoch: 5 - loss:  0.7302
  Best loss updated to 0.7302. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.12it/s]
Epoch: 6 - loss:  0.7289
  Best loss updated to 0.7289. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.15it/s]
Epoch: 7 - loss:  0.7283
  Best loss updated to 0.7283. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.16it/s]
Epoch: 8 - loss:  0.7280
  Best loss updated to 0.7280. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.17it/s]
Epoch: 9 - loss:  0.7278
  Best loss updated to 0.7278. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.17it/s]
Epoch: 10 - loss:  0.7277
  Best loss updated to 0.7277. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.20it/s]
Epoch: 11 - loss:  0.7276
  Best loss updated to 0.7276. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.17it/s]
Epoch: 12 - loss:  0.7276
  EarlyStopping counter: 1 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.18it/s]
Epoch: 13 - loss:  0.7276
  EarlyStopping counter: 2 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.21it/s]
Epoch: 14 - loss:  0.7276
  EarlyStopping counter: 3 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.14it/s]
Epoch: 15 - loss:  0.7276
  EarlyStopping counter: 4 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.16it/s]
Epoch: 16 - loss:  0.7275
  Best loss updated to 0.7275. Model saved.
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.12it/s]
Epoch: 17 - loss:  0.7275
  EarlyStopping counter: 1 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.14it/s]
Epoch: 18 - loss:  0.7275
  EarlyStopping counter: 2 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.14it/s]
Epoch: 19 - loss:  0.7275
  EarlyStopping counter: 3 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.14it/s]
Epoch: 20 - loss:  0.7275
  EarlyStopping counter: 4 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.14it/s]
Epoch: 21 - loss:  0.7275
  EarlyStopping counter: 5 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.13it/s]
Epoch: 22 - loss:  0.7275
  EarlyStopping counter: 6 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.15it/s]
Epoch: 23 - loss:  0.7275
  EarlyStopping counter: 7 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.13it/s]
Epoch: 24 - loss:  0.7275
  EarlyStopping counter: 8 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.13it/s]
Epoch: 25 - loss:  0.7275
  EarlyStopping counter: 9 out of 10
100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 980/980 [01:14<00:00, 13.13it/s]
Epoch: 26 - loss:  0.7275
  EarlyStopping counter: 10 out of 10
Loading the best model state...
Loading best model from /Users/jeong-yunseong/Documents/programming/Phase_2/./analyze/explainer_checkpoints/real/PGExplainer_GINGRU_ 0.7275.pth...
'''

# %%
epochs = []
losses = []
import re
import matplotlib.pyplot as plt
# 정규식 패턴: "Epoch: 숫자 - loss: 숫자.숫자"
# 예: Epoch: 1 - loss:  17.4351
pattern = r"Epoch:\s*(\d+)\s*-\s*loss:\s*([0-9.]+)"

for line in log.strip().split("\n"):
    match = re.search(pattern, line)
    if match:
        epochs.append(int(match.group(1)))
        losses.append(float(match.group(2)))

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, losses, marker='o', linestyle='-', color='b', label='Training Loss')

# 제목 및 라벨 설정
plt.title("Training Loss per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

# X축 틱 설정 (데이터가 많지 않으므로 모든 에포크 표시 가능)
if len(epochs) > 0:
    plt.xticks(range(min(epochs), max(epochs)+1, 1))

plt.tight_layout()
plt.show()

# %%
import sys
import os

CURDIR = os.getcwd()
PARDIR = os.path.join(CURDIR, '..')
sys.path.append(PARDIR)

import torch
import torch_geometric
from teds_tensor_dataset import TEDSTensorDataset
from models.gin_gru import GinGru

root = os.path.join(PARDIR, 'data_tensor_cache')
mi_dict_path = os.path.join(root, 'data', 'mi_dict_static.pickle')

dataset = TEDSTensorDataset(root)

col_list, col_dims, ad_col_index, dis_col_index = dataset.col_info

from utils.processing_utils import mi_edge_index_improved, mi_edge_index_batched

edge_index_batched = mi_edge_index_batched(batch_size=32,
                                           num_nodes=len(ad_col_index),
                                           mi_dict_path=mi_dict_path)

edge_index_single = mi_edge_index_batched(batch_size=1,
                                           num_nodes=len(ad_col_index),
                                           mi_dict_path=mi_dict_path)

device = torch.device('cpu')

model = GinGru(
    batch_size=32,
    col_list=col_list,
    col_dims=col_dims,
    ad_col_index=ad_col_index,
    dis_col_index=dis_col_index,
    embedding_dim=32,
    gin_hidden_channel=32,
    train_eps=True,
    gin_layers=2,
    gru_hidden_channel=64
)
